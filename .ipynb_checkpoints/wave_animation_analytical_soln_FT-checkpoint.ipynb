# %%
# import
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
# constants
L = 3
c = 1
k = 0.2
fps_play = 30

x_array_domain = np.linspace(0, L, 30)
t_array_play = np.arange(0, 20, 1/fps_play)
dt_play = t_array_play[1]-t_array_play[1]

t_array_integrate = np.linspace(-50, 50, 500) # practical limit for t integration
dt = t_array_integrate[1]-t_array_integrate[0]
omega_array = np.arange(
    -np.pi/dt, np.pi/dt, 2*np.pi/t_array_integrate[-1]
) # practical limit for omega integration

# %%
# define boundary function
def phi(t):
    sigma = 5
    return np.exp(-sigma * (t - 1)**2)

# sample phi(t), take FT to get phi_hat(omega)
phi_t = phi(t_array_integrate)
phi_hat_omega = np.array(
    [np.trapz(phi_t * np.exp(-1j * omega * t_array_integrate), x=t_array_integrate) for omega in omega_array]
)

# %%
# visualize the spectrum
plt.figure(figsize=(10, 4))
plt.plot(omega_array, np.real(phi_hat_omega))
plt.xlabel('omega')
plt.ylabel('phi_hat_omega')
plt.grid(True)
plt.show()

# %%
# define integrand
# create 3D grids for omega, x, and t
omega_grid, x_grid, t_grid = np.meshgrid(omega_array, x_array_domain, t_array_play, indexing='ij')

# beta and gamma grids
beta_grid = (1 / c) * np.sqrt(
    (omega_grid**2 + np.sqrt(omega_grid**4 + omega_grid**2 * k**2)) / 2
)
gamma_grid = -(np.sign(omega_grid * k) / c) * np.sqrt(
    (-omega_grid**2 + np.sqrt(omega_grid**4 + omega_grid**2 * k**2)) / 2
)

# u_omega grid
num_grid = (np.exp(gamma_grid * (2*L - x_grid)) * np.exp(1j * beta_grid * x_grid) -
    np.exp(1j * beta_grid * (2*L - x_grid)) * np.exp(gamma_grid * x_grid))
denom_grid = (np.exp(2 * gamma_grid * L) - 
    np.exp(2 * 1j * beta_grid * L))

u_omega_x_t = np.exp(1j * omega_grid * t_grid) * num_grid / denom_grid

# %%
# integrate back to get u(x, t)
# broadcast phi_hat_omega across dimensions of omega_grid, x_grid, t_grid
phi_hat_omega_grid = phi_hat_omega[:, np.newaxis, np.newaxis]

# get integrand grid
integrand_grid = u_omega_x_t * phi_hat_omega_grid / (2 * np.pi)

# perform integration over omega
u_x_t = np.trapz(integrand_grid, x=omega_array, axis=0)

# %%
# plot u(0, t) as a check
fig0, ax0 = plt.subplots()
ax0.plot(t_array_play, np.real(u_x_t[0, :]))
ax0.set_xlabel('t')
ax0.set_ylabel('u(0, t)')
plt.show()

# %%
# initial plot
fig, ax = plt.subplots()
initial_data = u_x_t[:, 0]
line, = ax.plot(x_array_domain, np.real(initial_data), color='blue')
ax.set_xlim(0, L)
ax.set_ylim(-2, 2)
ax.set_title('Re u(x, t)')
ax.set_xlabel('x')
ax.set_ylabel('')

# update function for animation
def update(index):
    y_data = np.real(u_x_t[:, index])
    line.set_ydata(np.real(y_data))

    t_curr = t_array_play[index]
    prog = index/len(t_array_play)
    ax.set_title(f'Re u(x, t) at t = {t_curr:.2f}')
    
    print(f"\rprogress = {prog:.2f}           ", end = "")
    return line,

# create animation
ani = FuncAnimation(fig, update, frames=range(len(t_array_play)), blit=True)

# save the animation (requires ffmpeg installed)
ani.save('gaussianwave_animation1.mp4', fps=fps_play, extra_args=['-vcodec', 'libx264'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 23
#      20     return line,
#      22 # create animation
# ---> 23 ani = FuncAnimation(fig, update, frames=range(len(t_array_play)), blit=True)
#      25 # save the animation (requires ffmpeg installed)
#      26 ani.save('gaussianwave_animation1.mp4', fps=fps_play, extra_args=['-vcodec', 'libx264'])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1686, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1683 # Needs to be initialized so the draw functions work without checking
#    1684 self._save_seq = []
# -> 1686 super().__init__(fig, **kwargs)
#    1688 # Need to reset the saved seq, since right now it will contain data
#    1689 # for a single frame from init, which is not what we want.
#    1690 self._save_seq = []
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1408, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1406 if event_source is None:
#    1407     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1408 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:876, in Animation.__init__(self, fig, event_source, blit)
#     873 self._close_id = self._fig.canvas.mpl_connect('close_event',
#     874                                               self._stop)
#     875 if self._blit:
# --> 876     self._setup_blit()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1201, in Animation._setup_blit(self)
#    1199 self._drawn_artists = []
#    1200 # _post_draw needs to be called first to initialize the renderer
# -> 1201 self._post_draw(None, self._blit)
#    1202 # Then we need to clear the Frame for the initial draw
#    1203 # This is typically handled in _on_resize because QT and Tk
#    1204 # emit a resize event on launch, but the macosx backend does not,
#    1205 # thus we force it here for everyone for consistency
#    1206 self._init_draw()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1156, in Animation._post_draw(self, framedata, blit)
#    1154     self._blit_draw(self._drawn_artists)
#    1155 else:
# -> 1156     self._fig.canvas.draw_idle()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:2078, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2076 if not self._is_idle_drawing:
#    2077     with self._idle_draw_cntx():
# -> 2078         self.draw(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backends\backend_agg.py:400, in FigureCanvasAgg.draw(self)
#     396 # Acquire a lock on the shared font cache.
#     397 with RendererAgg.lock, \
#     398      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     399       else nullcontext()):
# --> 400     self.figure.draw(self.renderer)
#     401     # A GUI class may be need to update a window using this draw, so
#     402     # don't forget to call the superclass.
#     403     super().draw()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\figure.py:3135, in Figure.draw(self, renderer)
#    3132 finally:
#    3133     self.stale = False
# -> 3135 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\backend_bases.py:1259, in Event._process(self)
#    1257 def _process(self):
#    1258     """Generate an event with name ``self.name`` on ``self.canvas``."""
# -> 1259     self.canvas.callbacks.process(self.name, self)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:309, in CallbackRegistry.process(self, s, *args, **kwargs)
#     307 except Exception as exc:
#     308     if self.exception_handler is not None:
# --> 309         self.exception_handler(exc)
#     310     else:
#     311         raise
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:96, in _exception_printer(exc)
#      94 def _exception_printer(exc):
#      95     if _get_running_interactive_framework() in ["headless", None]:
# ---> 96         raise exc
#      97     else:
#      98         traceback.print_exc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\cbook\__init__.py:304, in CallbackRegistry.process(self, s, *args, **kwargs)
#     302 if func is not None:
#     303     try:
# --> 304         func(*args, **kwargs)
#     305     # this does not capture KeyboardInterrupt, SystemExit,
#     306     # and GeneratorExit
#     307     except Exception as exc:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:900, in Animation._start(self, *args)
#     897 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     899 # Now do any initial draw
# --> 900 self._init_draw()
#     902 # Add our callback for stepping the animation and
#     903 # actually start the event_source.
#     904 self.event_source.add_callback(self._step)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1740, in FuncAnimation._init_draw(self)
#    1732         warnings.warn(
#    1733             "Can not start iterating the frames for the initial draw. "
#    1734             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1737             "it may be exhausted due to a previous display or save."
#    1738         )
#    1739         return
# -> 1740     self._draw_frame(frame_data)
#    1741 else:
#    1742     self._drawn_artists = self._init_func()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\animation.py:1759, in FuncAnimation._draw_frame(self, framedata)
#    1755     self._save_seq = self._save_seq[-self._save_count:]
#    1757 # Call the func with framedata and args. If blitting is desired,
#    1758 # func needs to return a sequence of any artists that were modified.
# -> 1759 self._drawn_artists = self._func(framedata, *self._args)
#    1761 if self._blit:
#    1763     err = RuntimeError('The animation function must return a sequence '
#    1764                        'of Artist objects.')
#
# Cell In[8], line 17, in update(index)
#      14 line.set_ydata(np.real(y_data))
#      16 prog = t_array_play[index]/len(t_array_play)
# ---> 17 ax.set_title(f'Re u(x, t) at t = {tj:.2f}')
#      19 print(f"\rprogress = {prog:.2f}           ", end = "")
#      20 return line,
#
# NameError: name 'tj' is not defined
